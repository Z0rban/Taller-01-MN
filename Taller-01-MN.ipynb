# %%
def eqn(x:int) -> int:
    return (x**3)-(7*x**2)+4*x+12

# %%
import numpy as np


##Genera 100 datos del -10 al 10
Xs, step = np.linspace(-10,10,num=15,retstep=True)

# %%
Ys= []
for x in Xs:
    y = eqn(x)
    Ys.append(y)
    print(f"x= {x:.2f} \ty= {y:.2e}")
Ys
# Out:
# x= -10.00 	y= -1.73e+03
# x= -8.57 	y= -1.17e+03
# x= -7.14 	y= -7.38e+02
# x= -5.71 	y= -4.26e+02
# x= -4.29 	y= -2.12e+02
# x= -2.86 	y= -7.99e+01
# x= -1.43 	y= -1.09e+01
# x= 0.00 	y= 1.20e+01
# x= 1.43 	y= 6.34e+00
# x= 2.86 	y= -1.04e+01
# x= 4.29 	y= -2.07e+01
# x= 5.71 	y= -7.13e+00
# x= 7.14 	y= 4.79e+01
# x= 8.57 	y= 1.62e+02
# x= 10.00 	y= 3.52e+02
# [np.float64(-1728.0),
#  np.float64(-1166.3090379008745),
#  np.float64(-738.1457725947521),
#  np.float64(-426.01749271137027),
#  np.float64(-212.43148688046645),
#  np.float64(-79.89504373177842),
#  np.float64(-10.915451895043741),
#  np.float64(12.0),
#  np.float64(6.344023323615158),
#  np.float64(-10.39067055393587),
#  np.float64(-20.711370262390666),
#  np.float64(-7.125364431486872),
#  np.float64(47.86005830903788),
#  np.float64(161.73760932944623),
#  np.float64(352.0)]

# %%
from matplotlib import pyplot as plt

#import seabor as sns ## alternativa

_ = plt.plot(Xs,Ys, marker=".", color="blue", linestyle=":")
_ = plt.xlabel("Eje x")
_ = plt.ylabel("Eje y")
plt.title("Gráfica de función cúbica")
plt.legend(["$y(x)=x^3-7x^2+4x+12$"])
plt.grid()
plt.show()

## TAREA HACER ZOOM
